# %%
# pip install pandas openpyxl 
# # openpyxl is a library used by pandas to read and write Excel files.
 # pandas is a powerful data manipulation library in Python that provides data structures and functions for working with structured data, such as tabular data in Excel files. The openpyxl library is used by pandas to read and write Excel files, allowing you to easily import and export data between Excel and pandas DataFrames.
#   pip list # pip list is a command used to display a list of all the installed Python packages in your environment. It shows the package name and its version number, allowing you to verify that the necessary libraries (like pandas and openpyxl) are installed for your project.

import pandas as pd 

df = pd.read_excel("sales.xlsx")

print(df.head())
# Out:
#     Region  Product1  Product2  Product3
# 0    North       100       200       150
# 1    South        80       220       130
# 2     East        90       210       160
# 3     West       120       180       140
# 4  Central       110       190       170

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\themi\AppData\Local\Python\pythoncore-3.14-64\python.exe
